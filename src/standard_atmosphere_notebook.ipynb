# %%
# Third Party
import numpy as np
from pandas import DataFrame

# My standard atmosphere wrapper
from standard_atm import get_atm

# %%
# Define an atmosphere
height = np.linspace(0,10,100)
standard_atmosphere = get_atm(height, lat='standard', vcoord='height')

# Convert to a data Frame
sa_frame = DataFrame(standard_atmosphere)

print(sa_frame)
# Out:
#        pressure     height      density  temperature  ozone_mixing_ratio  \
# 0   1013.250000   0.000000  1225.000000   288.149994        6.143674e-08
# 1   1001.679321   0.101010  1213.585815   287.493439        5.866553e-08
# 2    990.108582   0.202020  1202.171753   286.836853        5.589433e-08
# 3    978.537903   0.303030  1190.757568   286.180298        5.312312e-08
# 4    966.967163   0.404040  1179.343384   285.523743        5.035191e-08
# 5    955.396484   0.505050  1167.929321   284.867157        4.758071e-08
# 6    943.825745   0.606061  1156.515137   284.210602        4.480950e-08
# 7    932.255066   0.707071  1145.101074   283.554047        4.203829e-08
# 8    920.684326   0.808081  1133.686890   282.897461        3.926709e-08
# 9    909.113647   0.909091  1122.272705   282.240906        3.649588e-08
# 10   897.652527   1.010101  1110.929321   281.584351        3.428118e-08
# 11   887.177795   1.111111  1100.222168   280.927765        3.707494e-08
# ...
